# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
import warnings as w
w.filterwarnings('ignore')
# Out:
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_1361.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_4264.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_7985.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_2060.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_9645.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_555.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_2729.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_9745.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_4115.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_7071.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_9367.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_4610.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_5307.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_6796.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_5312.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_8693.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_1539.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_7023.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_689.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_4204.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_2491.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_6317.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_7825.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_502.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_7312.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Plane/augmented_0_4505.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_348.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_4178.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_8833.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_395.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_1714.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_7528.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_8575.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_3383.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_8289.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_442.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_7691.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_1379.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_4573.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_6796.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_8690.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_7451.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_9101.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_8066.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_6186.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_5833.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_9840.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_910.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_929.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_9539.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_4139.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_7807.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_9611.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_1424.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_5709.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_2452.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_610.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_5988.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_4704.png
# /kaggle/input/doodle-augmented-data/AugData/val/Key/augmented_0_9702.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_7553.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_5449.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_8580.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_8750.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_3078.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_9010.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_6407.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_5185.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_139.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_6412.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_9037.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_9929.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_1421.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_2412.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_9862.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_9508.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_6967.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_9379.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_5560.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_8625.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_9606.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_837.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_5299.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_6270.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_6261.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_6651.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_2138.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_722.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_7350.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_4093.png
# /kaggle/input/doodle-augmented-data/AugData/val/Cloud/augmented_0_8483.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_1278.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_1535.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_7605.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_7976.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_4228.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_591.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_9704.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_607.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_2971.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_4719.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_1662.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_6369.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_9991.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_8364.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_6248.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_9941.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_3529.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_2511.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_6088.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_393.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_5505.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_4805.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_5895.png
# /kaggle/input/doodle-augmented-data/AugData/val/Book/augmented_0_2705.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_1302.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_7287.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_3956.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_7115.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_7974.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_5720.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_8497.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_4655.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_2299.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_4220.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_6983.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_2341.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_1601.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_3756.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_3790.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_2195.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_2744.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_4850.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_3676.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_8929.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_9727.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_1503.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_5487.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_2833.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_8980.png
# /kaggle/input/doodle-augmented-data/AugData/val/Butterfly/augmented_0_8023.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_6075.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_5891.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_8057.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_5526.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_8599.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_8417.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_6583.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_598.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_9577.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_1314.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_8444.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_7260.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_6556.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_1618.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_7863.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_5875.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_1260.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_2855.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_2864.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_7247.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_7065.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_4647.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_1410.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_6458.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_2966.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_1276.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_124.png
# /kaggle/input/doodle-augmented-data/AugData/val/Hard Hat/augmented_0_6315.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_1312.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_6596.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_3350.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_4473.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_6918.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_3568.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_7737.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_7860.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_8600.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_9147.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_2190.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_3991.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_3945.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_5437.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_6107.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_5347.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_678.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_9222.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_8830.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_2455.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_7805.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_5920.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_6903.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_8045.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_1533.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_3032.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_8895.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_96.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_3633.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_8514.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_8190.png
# /kaggle/input/doodle-augmented-data/AugData/val/Flower/augmented_0_3388.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_6273.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_4947.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_9149.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_6608.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_3318.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_7233.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_4514.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_7724.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_8383.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_7225.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_3881.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_1358.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_5117.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_1624.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_8938.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_6470.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_7320.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_4694.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_659.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_401.png
# /kaggle/input/doodle-augmented-data/AugData/val/Apple/augmented_0_5859.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_9471.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_2.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_3625.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_31.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_8498.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_6460.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_3759.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_7641.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_7717.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_3429.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_2005.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_6613.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_1350.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_3542.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_465.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_1329.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_6642.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_58.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_1694.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_3549.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_5364.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_6257.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_1202.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_5739.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_5299.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_1469.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bulb/augmented_0_4946.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_8563.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_5954.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_1188.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_1920.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_5368.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_4659.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_2801.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_6124.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_6979.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_9753.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_2533.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_2627.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_7953.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_9618.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_8628.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_4785.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_1512.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_7583.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_5820.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_8662.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_1344.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_79.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_1056.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_9768.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_9799.png
# /kaggle/input/doodle-augmented-data/AugData/val/Ice Cream/augmented_0_9762.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_7278.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_5983.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_8557.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_5388.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_988.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_3869.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_6229.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_4726.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_5569.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_554.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_4953.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_3773.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_8044.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_7102.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_8298.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_6496.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_1220.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_9764.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_6724.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_5080.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_4493.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_5701.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_3509.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_6673.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_4855.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_4709.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_1241.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_7064.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_2028.png
# /kaggle/input/doodle-augmented-data/AugData/val/Car/augmented_0_4505.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_2726.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_9076.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_7810.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_8458.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_205.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_648.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_3372.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_1476.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_425.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_2617.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_9145.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_5039.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_8867.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_3657.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_2139.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_2677.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_777.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_952.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_3990.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_8593.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_3963.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_5108.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_4723.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_1202.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_2902.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_9542.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_9350.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_4197.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_3594.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_6998.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_6677.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_8055.png
# /kaggle/input/doodle-augmented-data/AugData/val/House/augmented_0_5615.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_4008.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_9076.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_1184.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_9940.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_2697.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_5230.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_5116.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_9745.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_1021.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_1135.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_3512.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_7164.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_4950.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_9566.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_3222.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_8298.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_5996.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_9597.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_815.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_1945.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_9685.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_4796.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_6084.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_8401.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_2708.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_6111.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_2428.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_5354.png
# /kaggle/input/doodle-augmented-data/AugData/val/Tree/augmented_0_3977.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_7851.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_3925.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_4830.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_1309.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_3508.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_4521.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_5845.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_3775.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_3953.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_2993.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_6429.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_4199.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_5558.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_9268.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_1379.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_4501.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_9566.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_5858.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_8392.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_4820.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_7996.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_2933.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_5707.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_5899.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_5108.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_7183.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_3518.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_4681.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_1504.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_6009.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_5598.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_3342.png
# /kaggle/input/doodle-augmented-data/AugData/val/Guitar/augmented_0_1284.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_6362.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_9399.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_3207.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_4465.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_4278.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_990.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_6402.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_7560.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_4021.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_137.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_7629.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_4323.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_8605.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_5434.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_2131.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_5145.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_9078.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_3944.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_9188.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_9157.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_9994.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_6855.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_7364.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_6867.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_2169.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_4012.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_3710.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_7866.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_6849.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_4702.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_9799.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_7126.png
# /kaggle/input/doodle-augmented-data/AugData/val/Paper Boat/augmented_0_5632.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_9495.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_1336.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_7416.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_9859.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_4059.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_8823.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_5070.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_2414.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_6407.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_1262.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_5554.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_2238.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_8558.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_173.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_1109.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_1898.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_2111.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_5555.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_5545.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_6.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_5047.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_7704.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_5505.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_6715.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_7525.png
# /kaggle/input/doodle-augmented-data/AugData/val/Fish/augmented_0_1034.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_661.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_9969.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_8285.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_3780.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_2518.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_5026.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_7078.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_155.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_6692.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_5411.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_5103.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_3021.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_5914.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_4427.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_3963.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_699.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_5406.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_8223.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_6500.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_8354.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_8569.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_8596.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_1866.png
# /kaggle/input/doodle-augmented-data/AugData/val/Bicycle/augmented_0_508.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_1848.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_2217.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_8280.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_8381.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_280.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_5619.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_5520.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_5670.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_9754.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_4815.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_59.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_6640.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_7162.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_1364.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_3527.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_5790.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_4113.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_9462.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_4427.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_7049.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_2864.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_8927.png
# /kaggle/input/doodle-augmented-data/AugData/val/Diamond/augmented_0_8957.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_7566.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_873.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_7262.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_157.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_8891.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_4894.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_7934.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_2152.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_5869.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_7212.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_3463.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_5036.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_368.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_9956.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_8749.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_6095.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_1573.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_872.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_1866.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_3528.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_5570.png
# /kaggle/input/doodle-augmented-data/AugData/val/Chair/augmented_0_3655.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_4361.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_6425.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_4075.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_8963.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_3576.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_4494.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_8786.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_6703.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_5292.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_8081.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_2360.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_3660.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_2193.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_6835.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_1541.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_4491.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_3193.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_6963.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_2528.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_9813.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_497.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_245.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_8465.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_3453.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_1313.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_5336.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_3832.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_3195.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_3810.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_8187.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_3772.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_722.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_4842.png
# /kaggle/input/doodle-augmented-data/AugData/val/Smartphone/augmented_0_6263.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_822.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_3684.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_914.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_9700.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_2381.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_7085.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_8685.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_1755.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_8817.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_8449.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_9915.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_2046.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_5089.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_8559.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_3525.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_4815.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_9794.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_4877.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_7845.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_7476.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_3560.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_2760.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_7292.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_4984.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_410.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_8480.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_2195.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_4636.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_9679.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_3641.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_8593.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_9382.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_517.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_2810.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_7491.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_200.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_9807.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_166.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_9449.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_2403.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_9972.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_9329.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_3852.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_3072.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_7126.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_7834.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_1668.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_3618.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_1658.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_1905.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_812.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_772.png
# /kaggle/input/doodle-augmented-data/AugData/test/Paper Plane/augmented_0_6315.png
# /kaggle/input/doodle-augmented-data/AugData/test/Key/augmented_0_661.png
# /kaggle/input/doodle-augmented-data/AugData/test/Key/augmented_0_145.png
# /kaggle/input/doodle-augmented-data/AugData/test/Key/augmented_0_2937.png
# /kaggle/input/doodle-augmented-data/AugData/test/Key/augmented_0_1361.png
# /kaggle/input/doodle-augmented-data/AugData/test/Key/augmented_0_5124.png
# /kaggle/input/doodle-augmented-data/AugData/test/Key/augmented_0_1082.png
# /kaggle/input/doodle-augmented-data/AugData/test/Key/augmented_0_475.png
# /kaggle/input/doodle-augmented-data/AugData/test/Key/augmented_0_85.png
# /kaggle/input/doodle-augmented-data/AugData/test/Key/augmented_0_896.png
# /kaggle/input/doodle-augmented-data/AugData/test/Key/augmented_0_9850.png
# /kaggle/input/doodle-augmented-data/AugData/test/Key/augmented_0_6540.png
# ...
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8345.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2783.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5774.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8095.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_842.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7841.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_392.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_675.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6161.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2414.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5715.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5892.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2396.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7263.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2355.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2159.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_425.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3162.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6530.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9369.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_104.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2078.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5090.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_426.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3240.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9027.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_4780.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2294.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2000.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1006.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1546.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5519.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_4323.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2831.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_121.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1955.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8575.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6598.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8616.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_974.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3102.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7671.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5642.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8112.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6932.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2807.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7223.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6690.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_798.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5479.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_253.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1198.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_347.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1904.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3919.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3602.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5278.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_977.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3403.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9148.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7732.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2611.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3845.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1450.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5181.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_581.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_4109.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_943.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6331.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8189.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_808.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6073.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5953.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_4459.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5736.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1347.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1415.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1676.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3906.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6377.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2063.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3694.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5201.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1052.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8690.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2328.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6924.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8329.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6495.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9624.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8680.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6822.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5927.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6438.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8375.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1688.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2367.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9272.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1627.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5602.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2940.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9795.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_4895.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3969.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7996.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8949.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1711.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_4472.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_58.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7400.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9937.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8461.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_242.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7728.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8396.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3431.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8254.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2933.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1991.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2828.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9530.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6285.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1494.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2555.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2164.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2987.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_520.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2825.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1441.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5503.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8068.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2076.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3589.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_4825.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5268.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8356.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1728.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3522.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1536.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2449.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7401.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7377.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1715.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7491.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6607.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1337.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_4246.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_291.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9946.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_615.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3183.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2962.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_196.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9041.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_162.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1253.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_791.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1047.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5283.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7442.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7351.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3184.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6569.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6763.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9227.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6088.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6794.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7969.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5413.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5270.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_2268.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7995.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6554.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7533.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1909.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_8703.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3683.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_9253.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6566.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3082.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_305.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_4822.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5600.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_5847.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3399.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3631.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3643.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1386.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_458.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_3533.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1420.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1828.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_7056.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_1865.png
# /kaggle/input/doodle-augmented-data/AugData/train/Smartphone/augmented_0_6128.png

# %%
import os
import numpy as np
import tensorflow as tf
import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from keras.applications import VGG16
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from keras.metrics import Precision, Accuracy, AUC, Recall
import matplotlib.pyplot as plt

# %%
# Set the seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Define constants
image_size = (224, 224)
batch_size = 32
num_classes = 20
train_dir = '/kaggle/input/doodle-augmented-data/AugData/train'
val_dir = '/kaggle/input/doodle-augmented-data/AugData/val'
test_dir = '/kaggle/input/doodle-augmented-data/AugData/test'


# Data augmentation and normalization
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=20,
    fill_mode='nearest'

)

val_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=20,
    fill_mode='nearest'
    
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load and split the data into train and validation sets
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)

validation_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
)
# Out:
# Found 3991 images belonging to 20 classes.
# Found 562 images belonging to 20 classes.
# Found 1164 images belonging to 20 classes.

# %%
# Load the VGG16 model with pre-trained weights
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(image_size[0], image_size[1], 3),classes=num_classes)

# Set the layers of the pre-trained model to be non-trainable
base_model.trainable = False

# Build the model
model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 20)                5140
#
# =================================================================
# Total params: 21,142,612
# Trainable params: 6,427,924
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Define early stopping
early_stopping = EarlyStopping(patience=3, monitor ='val_loss', restore_best_weights=True)

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.n // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.n // batch_size,
    epochs=20,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/20
# 124/124 [==============================] - 77s 552ms/step - loss: 0.7181 - accuracy: 0.8227 - val_loss: 0.2221 - val_accuracy: 0.9467
# Epoch 2/20
# 124/124 [==============================] - 58s 470ms/step - loss: 0.1157 - accuracy: 0.9702 - val_loss: 0.0918 - val_accuracy: 0.9743
# Epoch 3/20
# 124/124 [==============================] - 59s 479ms/step - loss: 0.0592 - accuracy: 0.9866 - val_loss: 0.0646 - val_accuracy: 0.9798
# Epoch 4/20
# 124/124 [==============================] - 60s 485ms/step - loss: 0.0595 - accuracy: 0.9826 - val_loss: 0.0462 - val_accuracy: 0.9926
# Epoch 5/20
# 124/124 [==============================] - 60s 484ms/step - loss: 0.0476 - accuracy: 0.9843 - val_loss: 0.0664 - val_accuracy: 0.9853
# Epoch 6/20
# 124/124 [==============================] - 61s 490ms/step - loss: 0.0449 - accuracy: 0.9869 - val_loss: 0.0614 - val_accuracy: 0.9779
# Epoch 7/20
# 124/124 [==============================] - 60s 481ms/step - loss: 0.0490 - accuracy: 0.9859 - val_loss: 0.0566 - val_accuracy: 0.9835

# %%
# Printing the metrics
import matplotlib.pyplot as plt

plt.plot(history.history['val_loss'],label='val_loss')
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_accuracy'],label='val_accuracy')
plt.plot(history.history['accuracy'],label='accuracy')
plt.legend()
plt.plot()
# Out:
# []

# %%
model.evaluate(test_generator)
# Out:
# [0.02972457744181156, 0.988831639289856]

# %% [markdown]
# model.save('/kaggle/working/vgg16_model.h5')

# %%
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
predictions = model.predict(test_generator)
predicted_labels = np.argmax(predictions, axis=1)
# Out:
# Found 1164 images belonging to 20 classes.
# 37/37 [==============================] - 3s 86ms/step

# %%
true_labels = test_generator.classes
from sklearn.metrics import precision_score, recall_score, roc_auc_score

precision = precision_score(true_labels, predicted_labels, average='macro')
recall = recall_score(true_labels, predicted_labels, average='macro')
auc_roc = roc_auc_score(true_labels, predictions, multi_class='ovr')

print('Precision: ',precision)
print('Recall: ',recall)
print('ROC_AUC: ',auc_roc)
# Out:
# Precision:  0.989129382415228
# Recall:  0.9888344301939
# ROC_AUC:  0.9999942917574722
